# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/arthu/Documents/Projetos/DataVizLeagueofLegends/lol_ranked_games.csv")

# %%
#Verficando a presença de valores nulos
data.isnull().sum()
# Out:
# gameId                     0
# gameDuration               0
# hasWon                     0
# frame                      0
# goldDiff                   0
# expDiff                    0
# champLevelDiff             0
# isFirstTower               0
# isFirstBlood               0
# killedFireDrake            0
# killedWaterDrake           0
# killedAirDrake             0
# killedEarthDrake           0
# killedElderDrake           0
# lostFireDrake              0
# lostWaterDrake             0
# lostAirDrake               0
# lostEarthDrake             0
# lostElderDrake             0
# killedBaronNashor          0
# lostBaronNashor            0
# killedRiftHerald           0
# lostRiftHerald             0
# destroyedTopInhibitor      0
# destroyedMidInhibitor      0
# destroyedBotInhibitor      0
# lostTopInhibitor           0
# lostMidInhibitor           0
# lostBotInhibitor           0
# destroyedTopNexusTurret    0
# destroyedMidNexusTurret    0
# destroyedBotNexusTurret    0
# ...

# %%
data
# Out:
#             gameId  gameDuration  hasWon  frame  goldDiff  expDiff  \
# 0       4546233126       1443000       1     10      -448     -147
# 1       4546233126       1443000       1     12     -1306     -925
# 2       4546233126       1443000       1     14      2115     2578
# 3       4546233126       1443000       1     16      1195     2134
# 4       4546233126       1443000       1     18      2931     4382
# ...            ...           ...     ...    ...       ...      ...
# 242567  4402156483       1774000       0     30     -8523   -13498
# 242568  4379826739       1013000       0     10      -271    -1243
# 242569  4379826739       1013000       0     12     -2013    -3493
# 242570  4379826739       1013000       0     14     -2388    -4543
# 242571  4379826739       1013000       0     16     -5601    -7595
#
#         champLevelDiff  isFirstTower  isFirstBlood  killedFireDrake  ...  \
# 0                 -0.2             0             1                0  ...
# ...

# %%
#Verificando a correlação entre as colunas, temos que o principal indicador que referencia has won, são goldDiff, expDiff e,
#champLevelDiff, no entando essas 3 variáveis estão mais para a consequencia de se estar ganhando ou perdendo o jogo doque a causa em si.
data.corr()
# Out:
#                            gameId  gameDuration    hasWon     frame  goldDiff  \
# gameId                   1.000000      0.047204  0.006320  0.020165  0.001874
# gameDuration             0.047204      1.000000 -0.024658  0.434838 -0.015609
# hasWon                   0.006320     -0.024658  1.000000 -0.011317  0.607487
# frame                    0.020165      0.434838 -0.011317  1.000000 -0.018998
# goldDiff                 0.001874     -0.015609  0.607487 -0.018998  1.000000
# expDiff                  0.001443     -0.024492  0.575538 -0.039266  0.875950
# champLevelDiff           0.002741     -0.018444  0.580956 -0.026109  0.868697
# isFirstTower            -0.002368      0.203942  0.196205  0.595771  0.316139
# isFirstBlood            -0.003147      0.034195  0.025804  0.046087  0.028674
# killedFireDrake          0.016549      0.108987  0.181943  0.278606  0.209754
# killedWaterDrake         0.005688      0.119889  0.178357  0.295336  0.213073
# ...

# %%
#Dividndo o dataset entre partidas ganhas e partidas perdidas, dessa forma conseguimos realizar análises mais precisas e de acordo com nosso problema.
lost_matches = data[data['hasWon'] == 0]
win_matches = data[data['hasWon'] == 1]

# %%
#Agora com o dataset dividido vamos visualizar algumas médias separadas por partidas ganhas e perdidas.
lost_matches['wardsPlaced'].mean()
# Out:
# 56.28927221948415

# %%
win_matches['wardsPlaced'].mean()
# Out:
# 57.38187731726695

# %%
lost_matches['deaths'].mean()
# Out:
# 18.663767044521112

# %%
win_matches['deaths'].mean()
# Out:
# 14.003227621822035

# %%
win_matches['isFirstBlood'].mean()
# Out:
# 0.9995862023305084

# %%
lost_matches['isFirstBlood'].mean()
# Out:
# 0.9976753737473304

# %%
lost_matches['killedRiftHerald'].mean()
# Out:
# 0.4533185477246591

# %%
win_matches['killedRiftHerald'].mean()
# Out:
# 0.6761536679025424

# %%
win_matches['goldDiff'].mean()
# Out:
# 3304.5154263771187

# %%
lost_matches['goldDiff'].mean()
# Out:
# -3302.6111302776408

# %%
lost_matches['isFirstTower'].mean()
# Out:
# 0.5227205519960572

# %%
win_matches['isFirstTower'].mean()
# Out:
# 0.7134120100635594

# %%
win_matches['killedBaronNashor'].mean()
# Out:
# 0.20596365201271186

# %%
lost_matches['killedBaronNashor'].mean()
# Out:
# 0.0770658781008707

# %%
lost_matches['kills'].mean()
# Out:
# 14.27593231476918

# %%
win_matches['kills'].mean()
# Out:
# 18.522725768008474

# %%
lost_matches['wardsDestroyed'].mean()
# Out:
# 10.231107277805158

# %%
#Nesse momento eu concluo que os principais indicadores que influenciam na vitória ou derrota de uma partida são;
#A quantidade de arautos de barões feitos, e primeira torre destruida.
#No caso do barão times que ganham fazem quase três vezes mais o barão doque times que perdem
